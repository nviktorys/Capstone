# %%
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.plugins.logging_plugin import (
    LoggingPlugin,
)
from google.genai import types
from google.adk.tools import google_search
from google.genai import types
import asyncio
import pprint
import sys

from google.adk.tools.agent_tool import AgentTool

# %%
import os

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
model_name = "gemini-2.0-flash"

retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

short_config = types.GenerationConfig(
    max_output_tokens=500, # Limit response to 500 tokens
)

model_config = Gemini(
    model=model_name,
    retry_options=retry_config,
    generation_config=short_config,
    api_key=GOOGLE_API_KEY,
)

# %%
instructions = """
    You are a helpful shopping assistant. Use the tools provided to find products, compare prices, 
    and provide recommendations based on user preferences.
    When using the google_search tool, be specific with your queries to get the best results.
    Focus on finding high-quality products and good deals.
    Return up to 3 product recommendations with brief descriptions and prices in following JSON format:
    [
        {
            "seller": str = "Seller Name",
            "brand": str = "Brand Name",
            "product": str = "Product Name",
            "price": float = "Product Price",
            "user_review_score": float = "User Review Score"
        },
        ...
    ]
"""

shopping_agent = Agent(
    model=model_config,
    name="shopping_agent",
    description="An agent for shopping assistance",
    tools=[google_search],
    output_key="shopping_recommendations",
    instruction=instructions,
)
print("✅ shopping_agent created.")
# Out:
# ✅ shopping_agent created.

# %%
instructions = """
    You are a sustainability evaluation agent. Use the tools provided to research companies,
    focusing on their environmental impact, ethical practices, and sustainability initiatives.
    You should each brand provided in the list {shopping_recommendations} and evaluate their sustainability
    based on recent data. You need to use the google_search tool to find relevant information.
    Your key evaluation results should include:
    - Environmental Impact: Assess the brand's carbon footprint, resource usage, and waste management.
    - Ethical Practices: Evaluate labor practices, fair trade certifications, and community engagement.
    - Animal Welfare: Consider policies on animal testing and cruelty-free certifications.
    - Sustainability Initiatives: Look for programs or policies aimed at reducing environmental impact.
    For each of those categories make a score between 1 and 5, where 1 is poor and 5 is excellent.
    Scorring rules:
    - 1: Very poor performance, significant negative impact or unethical practices.
    - 2: Below average performance, some negative impact or questionable practices.
    - 3: Average performance, mention of ethical practices on company website but with no external validation.
    - 4: Good performance, mention of ethical practices on company website with some external validation.
    - 5: Excellent performance, mention of ethical practices on company website with strong external validation.
    Combine these scores to provide an overall sustainability rating for each brand.
    For each brand, return a brief evaluation in the following JSON format:
    [
        {
            "brand": str = "Brand Name",
            "environment_impact_score": int = 1-5,
            "ethical_practices_score": int = 1-5,
            "animal_welfare_score": int = 1-5,
            "sustainability_initiatives_score": int = 1-5,
            "overall_sustainability_rating": float = 1-5,
            "summary": str = "Brief summary of the evaluation for each of the categories and
                justification for the overall rating",
        },
        ...
    ]
"""

sustainability_evaluation_agent = Agent(
    model=model_config,
    name="sustainability_evaluation_agent",
    description="An agent for sustainability evaluation",
    tools=[google_search],
    output_key="sustainability_evaluation",
    instruction=instructions,
)
print("✅ sustainability_evaluation_agent created.")
# Out:
# ✅ sustainability_evaluation_agent created.

# %%
instructions = """
    You are a sustainable shopping assistant. Your task is to combine the shopping recommendations
    from the shopping_agent with the sustainability evaluations from the sustainability_evaluation_agent.
    Provide the user with a final list of product recommendations that balance quality, price, and sustainability.
    For each product recommendation, include the sustainability evaluation of the brand.
    Make single final recommendation for the best product in the following JSON format:
    {
            "brand": str = "Brand Name",
            "environment_impact_score": int = 1-5,
            "ethical_practices_score": int = 1-5,
            "animal_welfare_score": int = 1-5,
            "sustainability_initiatives_score": int = 1-5,
            "overall_sustainability_rating": float = 1-5,
            "user_review_score": float = "User Review Score"
            "summary": str = "Brief summary of the evaluation for each of the categories and
                justification for the overall rating",
    }
    Sustainability evaluation should be prioritized when making final recommendations.
"""

root_agent = Agent(
    model=model_config,
    name="sustainable_shopping_assistant",
    description="An agent that assists users in making sustainable shopping choices",
    tools=[AgentTool(agent=shopping_agent), AgentTool(agent=sustainability_evaluation_agent)],
    instruction=instructions,
)

# %%
runner = InMemoryRunner(
    agent=root_agent,
    plugins=[
        LoggingPlugin()
    ]
)

# %%
old_stdout = sys.stdout

log_file = open("agent_logs.log","w", encoding="utf-8")
sys.stdout = log_file

response = await runner.run_debug(
    "Find chrismas chocolate gift boxes."
)
# Out:
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.

# %%
sys.stdout = old_stdout
log_file.close()

# %%
# Print all responses
for i, event in enumerate(response):
    content = event.content
    for part in content.parts:
        if part.function_call:
            function_call = part.function_call
            print(f"*** Function Call in Agent {function_call.name} ***")
            pprint.pp(function_call.args["request"], depth=1)
        if part.function_response:
            function_response = part.function_response
            print(f"*** Function Response in Agent {function_response.name} ***")
            pprint.pp(function_response.response["result"], depth=1)
    metadata = event.usage_metadata
    if metadata:
        tokens = metadata.total_token_count
        print(f"Total tokens used in this event: {tokens}")
# Out:
# *** Function Call in Agent shopping_agent ***
# 'chrismas chocolate gift boxes'
# Total tokens used in this event: 318
# *** Function Response in Agent shopping_agent ***
# ('Here are some Christmas chocolate gift box options for 2025:\n'
#  '\n'
#  '*   **Compartes:** Offers a variety of Christmas chocolate gifts, including '
#  'the Green Pine Christmas Chocolate Gift Box. They also have advent '
#  'calendars, stocking stuffers, and chocolate bark.\n'
#  '*   **Cacao and Cardamom:** Offer luxury Christmas chocolate gift boxes with '
#  'selections like the Holiday 16-Piece Box, the Jewelry Box (24 Pieces), and '
#  'the Candy Cane Confections Gift Box. They also have a Holiday Chocolate '
#  'Advent Calendar.\n'
#  '*   **Mueller Chocolate Co.:** They offer several Christmas chocolate gift '
#  'boxes, including the Crowd Pleaser Gift Set, Classic Chocolate Gift Tower, '
#  'Seasonal Dark/Milk Chocolate Nonpareils, and Dark/Milk Chocolate Sea Salt '
#  'Caramel Piece Box.\n'
#  '*   **Hotel Chocolat:** Offers a range of Christmas Gift Boxes with a '
#  'variety of chocolates.\n'
#  '*   **Lindt:** They have a variety of Christmas chocolate boxes, including '
#  'LINDOR truffles and assorted flavor boxes.\n'
#  '*   **Cadbury Gifts Direct:** Offers Christmas chocolate gifts including '
#  'hampers, selection boxes, and advent calendars.\n'
#  '*   **Russell Stover:** Offers Christmas chocolate gift boxes, including '
#  'solid milk chocolate foil-wrapped Santas and assorted milk & dark chocolate '
#  'options.\n'
#  '\n'
#  'I can provide you with more specific recommendations if you share your '
#  'preferences, such as:\n'
#  '\n'
#  '*   **Preferred chocolate type:** (e.g., milk, dark, white, assorted)\n'
#  '*   **Dietary needs:** (e.g., vegan, gluten-free)\n'
#  '*   **Budget:**\n'
#  '*   **Recipient:** (e.g., family, friends, corporate)\n')
# *** Function Call in Agent sustainability_evaluation_agent ***
# 'Compartes'
# *** Function Call in Agent sustainability_evaluation_agent ***
# 'Cacao and Cardamom'
# *** Function Call in Agent sustainability_evaluation_agent ***
# 'Mueller Chocolate Co.'
# *** Function Call in Agent sustainability_evaluation_agent ***
# 'Hotel Chocolat'
# *** Function Call in Agent sustainability_evaluation_agent ***
# 'Lindt'
# *** Function Call in Agent sustainability_evaluation_agent ***
# 'Cadbury Gifts Direct'
# *** Function Call in Agent sustainability_evaluation_agent ***
# 'Russell Stover'
# Total tokens used in this event: 727
# *** Function Response in Agent sustainability_evaluation_agent ***
# ("Here's a sustainability evaluation of Compartes:\n"
#  '\n'
#  '\n'
#  '```json\n'
#  '[\n'
#  '  {\n'
#  '    "brand": "Compartes",\n'
#  '    "environment_impact_score": 4,\n'
#  '    "ethical_practices_score": 4,\n'
#  '    "animal_welfare_score": 3,\n'
#  '    "sustainability_initiatives_score": 4,\n'
#  '    "overall_sustainability_rating": 3.75,\n'
#  '    "summary": "Compartes has demonstrated a commitment to sustainability '
#  'through ethical sourcing and environmental stewardship. They source cocoa '
#  'beans from farms adhering to strict ethical standards, ensuring fair labor '
#  'practices and community development. The company also focuses on reducing '
#  'its environmental footprint by using renewable energy, reducing water usage, '
#  'and implementing waste recycling programs. They strive to use sustainable '
#  'packaging materials and minimize plastic usage. Although they claim to '
#  'source fair-trade chocolate, there is no mention of cruelty-free '
#  'certification, therefore the animal welfare score is average. Overall, '
#  'Compartes is dedicated to improving its sustainability goals."\n'
#  '  }\n'
#  ']\n'
#  '```')
# *** Function Response in Agent sustainability_evaluation_agent ***
# ('```json\n'
#  '[\n'
#  '  {\n'
#  '    "brand": "Cacao and Cardamom",\n'
#  '    "environment_impact_score": 3,\n'
#  '    "ethical_practices_score": 4,\n'
#  '    "animal_welfare_score": 5,\n'
#  '    "sustainability_initiatives_score": 3,\n'
#  '    "overall_sustainability_rating": 3.75,\n'
#  '    "summary": "Cacao and Cardamom demonstrates a mixed approach to '
#  'sustainability. On the environmental front, cocoa farming is associated with '
#  'deforestation, climate change, and soil degradation. While the brand '
#  "emphasizes ethical sourcing, it's crucial to verify the extent to which they "
#  'actively combat deforestation and promote biodiversity. Ethically, the brand '
#  'states that they take great care in sourcing ingredients ethically. They '
#  'also support chocolate makers from around the world that source cacao from '
#  'their own countries and have ethical standards. Cacao and Cardamom ensures '
#  'no animal products are used in their vegan collection. Their sustainability '
#  'initiatives include working with small farms committed to sustainable '
#  'practices. The overall rating reflects a need for increased transparency and '
#  'stronger validated environmental initiatives."\n'
#  '  }\n'
#  ']\n'
#  '```')
# *** Function Response in Agent sustainability_evaluation_agent ***
# ("Here's a sustainability evaluation for Mueller Chocolate Co., based on the "
#  'provided search results:\n'
#  '\n'
#  '\n'
#  '```json\n'
#  '[\n'
#  '  {\n'
#  '    "brand": "Mueller Chocolate Co.",\n'
#  '    "environment_impact_score": 2,\n'
#  '    "ethical_practices_score": 3,\n'
#  '    "animal_welfare_score": 3,\n'
#  '    "sustainability_initiatives_score": 2,\n'
#  '    "overall_sustainability_rating": 2.5,\n'
#  '    "summary": "Mueller Chocolate Co., a Philadelphia-based chocolatier with '
#  'over 40 years of history, demonstrates some awareness of sustainability, but '
#  'lacks extensive publicly available information to support a high rating. '
#  'Their environmental impact is rated as below average. While the company uses '
#  'small-batch techniques, information about their carbon footprint, resource '
#  'usage, and waste management is limited. Their ethical practices score is '
#  'average, as the company donates to local charities. However, there is no '
#  'mention of fair trade certifications or detailed labor practices. Their '
#  'animal welfare score is average due to the fact that ingredients like dairy '
#  'may be present in their products. Information about animal testing and '
#  'cruelty-free certifications is not available. The sustainability initiatives '
#  'score is below average, as while the company focuses on quality and '
#  'tradition, details on specific sustainability programs or policies aimed at '
#  'reducing environmental impact are lacking. Overall, Mueller Chocolate Co. '
#  'receives a rating of 2.5, indicating a need for greater transparency and '
#  'commitment to comprehensive sustainability practices."\n'
#  '  }\n'
#  ']\n'
#  '```')
# *** Function Response in Agent sustainability_evaluation_agent ***
# ("Here's a sustainability evaluation of Hotel Chocolat based on the provided "
#  'sources:\n'
#  '\n'
#  '\n'
#  '```json\n'
#  '[\n'
#  '  {\n'
#  '    "brand": "Hotel Chocolat",\n'
#  '    "environment_impact_score": 4,\n'
#  '    "ethical_practices_score": 4,\n'
#  '    "animal_welfare_score": 2,\n'
#  '    "sustainability_initiatives_score": 4,\n'
#  '    "overall_sustainability_rating": 3.5,\n'
#  '    "summary": "Hotel Chocolat demonstrates a strong commitment to '
#  'minimizing its environmental impact through various initiatives. They are '
#  'actively working to improve sustainable packaging, reduce energy '
#  'consumption, and manage food waste. They source close to 100% of their card '
#  'and paper packaging from Forest Stewardship Council (FSC) certified sources. '
#  'The company also recognizes the potential negative impacts of climate change '
#  'and has taken steps to mitigate these effects.\\n\\nHotel Chocolat has '
#  "'Engaged Ethics' program, and they work directly with cacao farmers in St. "
#  'Lucia and Ghana, paying premium prices and providing resources for '
#  'sustainable farming practices. They invest in agroforestry activities, '
#  'distribute shade tree and cacao seedlings, and provide hands-on labor '
#  'support for pruning.\\n\\nHotel Chocolat does not appear to have strong '
#  'animal welfare policies. The Good Shopping Guide gives them a poor rating '
#  'for animal welfare and notes they lack vegetarian/vegan verification. '
#  'Information about animal testing policies or cruelty-free certifications is '
#  'not readily available in the provided context.\\n\\nHotel Chocolat has '
#  "several sustainability initiatives, including a 'Planet Pledge'. They are "
#  'dedicated to reducing energy consumption and CO2 emissions. They also focus '
#  'on fighting food waste and turning waste into resources. For example, they '
#  'recycle food waste by-products from their chocolate factory '
#  'production.\\n\\nWhile Hotel Chocolat demonstrates a commitment to ethical '
#  'and sustainable practices, there is room for improvement, particularly in '
#  'the area of animal welfare. Their Engaged Ethics program and focus on '
#  'sustainable cocoa farming are commendable, but their lack of clear animal '
#  'welfare policies and certifications bring down the overall score."\n'
#  '  }\n'
#  ']\n'
#  '```')
# *** Function Response in Agent sustainability_evaluation_agent ***
# ('Here is a sustainability evaluation for Lindt, based on the provided '
#  'information:\n'
#  '\n'
#  '\n'
#  '```json\n'
#  '[\n'
#  '  {\n'
#  '    "brand": "Lindt",\n'
#  '    "environment_impact_score": 4,\n'
#  '    "ethical_practices_score": 4,\n'
#  '    "animal_welfare_score": 5,\n'
#  '    "sustainability_initiatives_score": 4,\n'
#  '    "overall_sustainability_rating": 4.25,\n'
#  '    "summary": "Lindt demonstrates a strong commitment to sustainability, '
#  'with various initiatives and targets set for 2025 and beyond. Their '
#  'environmental efforts include reducing deforestation, achieving net-zero '
#  'emissions by 2050, and designing recyclable packaging. Ethically, Lindt '
#  'focuses on improving the livelihoods of cocoa farmers through the Lindt & '
#  'Sprüngli Farming Program. They also have a policy banning animal testing. '
#  "While there's still progress to be made, particularly in achieving 100% "
#  "sustainable sourcing of cocoa products and reducing water usage, Lindt's "
#  'comprehensive approach and clear targets indicate a strong dedication to '
#  'sustainability."\n'
#  '  }\n'
#  ']\n'
#  '```')
# *** Function Response in Agent sustainability_evaluation_agent ***
# ("Here's an evaluation of Cadbury Gifts Direct based on the criteria you "
#  'provided:\n'
#  '\n'
#  '\n'
#  '```json\n'
#  '[\n'
#  '  {\n'
#  '    "brand": "Cadbury Gifts Direct",\n'
#  '    "environment_impact_score": 3,\n'
#  '    "ethical_practices_score": 3,\n'
#  '    "animal_welfare_score": 3,\n'
#  '    "sustainability_initiatives_score": 3,\n'
#  '    "overall_sustainability_rating": 3.0,\n'
#  '    "summary": "Cadbury Gifts Direct showcases average sustainability '
#  'efforts. Regarding environmental impact, Cadbury is making efforts to reduce '
#  'its impact and has a goal to have 100% of its cocoa volume sourced through '
#  'the Cocoa Life program by 2025. Cadbury uses recycled card in their gift '
#  'boxes. For ethical practices, Cadbury has faced criticism regarding child '
#  'labor in its cocoa supply chain. Cadbury has products certified by The Vegan '
#  'Society. The brand is working with Fairtrade to ensure cocoa is sourced '
#  'ethically. Cadbury has a long-standing partnership with Fairtrade, working '
#  'together on programs to ensure cocoa is sourced ethically. Also, the Cadbury '
#  'Foundation supports community development. Overall, Cadbury Gifts Direct is '
#  'taking steps toward sustainability, but there are still areas for '
#  'improvement."\n'
#  '  }\n'
#  ']\n'
#  '```')
# *** Function Response in Agent sustainability_evaluation_agent ***
# ('```json\n'
#  '[\n'
#  '  {\n'
#  '    "brand": "Russell Stover",\n'
#  '    "environment_impact_score": 3,\n'
#  '    "ethical_practices_score": 3,\n'
#  '    "animal_welfare_score": 3,\n'
#  '    "sustainability_initiatives_score": 3,\n'
#  '    "overall_sustainability_rating": 3.0,\n'
#  '    "summary": "Russell Stover is part of the Lindt & Sprüngli group and '
#  'adheres to their sustainability policies. Lindt & Sprüngli aims to have 80% '
#  'of raw and packaging materials covered by responsible sourcing programs by '
#  '2025 and 100% of cocoa products sourced through their Farming Program or '
#  'other responsible programs. They are also working on sustainable packaging '
#  'initiatives, aiming for 90% recyclability by 2025. Russell Stover follows '
#  "Lindt & Sprüngli's Supplier Code of Conduct and prioritizes employee safety. "
#  'The Lindt & Sprüngli Sustainability Plan focuses on improving livelihoods, '
#  'contributing to an intact environment, fostering collaboration, and '
#  'delighting consumers. Since Russell Stover does not provide information '
#  'about its own validation, a score of 3 is given."\n'
#  '  }\n'
#  ']\n'
#  '```')
# Total tokens used in this event: 2892

# %%
# Final recommendations:
print("*** Final Recommendations ***")
pprint.pp(response[-1].content.parts[-1].text, depth=1)
# Out:
# *** Final Recommendations ***
# ('```json\n'
#  '{\n'
#  '    "brand": "Lindt",\n'
#  '    "environment_impact_score": 4,\n'
#  '    "ethical_practices_score": 4,\n'
#  '    "animal_welfare_score": 5,\n'
#  '    "sustainability_initiatives_score": 4,\n'
#  '    "overall_sustainability_rating": 4.25,\n'
#  '    "user_review_score": 4.5,\n'
#  '    "summary": "Lindt demonstrates a strong commitment to sustainability. '
#  'Their environmental efforts include reducing deforestation, achieving '
#  'net-zero emissions by 2050, and designing recyclable packaging. Ethically, '
#  'Lindt focuses on improving the livelihoods of cocoa farmers through the '
#  'Lindt & Sprüngli Farming Program. They also have a policy banning animal '
#  "testing. Lindt's comprehensive approach and clear targets indicate a strong "
#  'dedication to sustainability."\n'
#  '}\n'
#  '```')

# %%
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.plugins.logging_plugin import (
    LoggingPlugin,
)
from google.genai import types
from google.adk.tools import google_search
from google.genai import types
import asyncio
import pprint

from google.adk.tools.agent_tool import AgentTool

# %%
import os

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
model_name = "gemini-2.0-flash"

retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

short_config = types.GenerationConfig(
    max_output_tokens=500, # Limit response to 500 tokens
)

model_config = Gemini(
    model=model_name,
    retry_options=retry_config,
    generation_config=short_config,
    api_key=GOOGLE_API_KEY,
)

# %%
instructions = """
    You are a helpful shopping assistant. Use the tools provided to find products, compare prices, 
    and provide recommendations based on user preferences.
    When using the google_search tool, be specific with your queries to get the best results.
    Focus on finding high-quality products and good deals.
    Return up to 3 product recommendations with brief descriptions and prices in following JSON format:
    [
        {
            "seller": str = "Seller Name",
            "brand": str = "Brand Name",
            "product": str = "Product Name",
            "price": float = "Product Price",
            "user_review_score": float = "User Review Score"
        },
        ...
    ]
"""

shopping_agent = Agent(
    model=model_config,
    name="shopping_agent",
    description="An agent for shopping assistance",
    tools=[google_search],
    output_key="shopping_recommendations",
    instruction=instructions,
)
print("✅ shopping_agent created.")
# Out:
# ✅ shopping_agent created.

# %%
instructions = """
    You are a sustainability evaluation agent. Use the tools provided to research companies,
    focusing on their environmental impact, ethical practices, and sustainability initiatives.
    You should each brand provided in the list {shopping_recommendations} and evaluate their sustainability
    based on recent data. You need to use the google_search tool to find relevant information.
    Your key evaluation results should include:
    - Environmental Impact: Assess the brand's carbon footprint, resource usage, and waste management.
    - Ethical Practices: Evaluate labor practices, fair trade certifications, and community engagement.
    - Animal Welfare: Consider policies on animal testing and cruelty-free certifications.
    - Sustainability Initiatives: Look for programs or policies aimed at reducing environmental impact.
    For each of those categories make a score between 1 and 5, where 1 is poor and 5 is excellent.
    Scorring rules:
    - 1: Very poor performance, significant negative impact or unethical practices.
    - 2: Below average performance, some negative impact or questionable practices.
    - 3: Average performance, mention of ethical practices on company website but with no external validation.
    - 4: Good performance, mention of ethical practices on company website with some external validation.
    - 5: Excellent performance, mention of ethical practices on company website with strong external validation.
    Combine these scores to provide an overall sustainability rating for each brand.
    For each brand, return a brief evaluation in the following JSON format:
    [
        {
            "brand": str = "Brand Name",
            "environment_impact_score": int = 1-5,
            "ethical_practices_score": int = 1-5,
            "animal_welfare_score": int = 1-5,
            "sustainability_initiatives_score": int = 1-5,
            "overall_sustainability_rating": float = 1-5,
            "summary": str = "Brief summary of the evaluation for each of the categories and
                justification for the overall rating",
        },
        ...
    ]
"""

sustainability_evaluation_agent = Agent(
    model=model_config,
    name="sustainability_evaluation_agent",
    description="An agent for sustainability evaluation",
    tools=[google_search],
    output_key="sustainability_evaluation",
    instruction=instructions,
)
print("✅ sustainability_evaluation_agent created.")
# Out:
# ✅ sustainability_evaluation_agent created.

# %%
instructions = """
    You are a sustainable shopping assistant. Your task is to combine the shopping recommendations
    from the shopping_agent with the sustainability evaluations from the sustainability_evaluation_agent.
    Provide the user with a final list of product recommendations that balance quality, price, and sustainability.
    For each product recommendation, include the sustainability evaluation of the brand.
    Make single final recommendation for the best product in the following JSON format:
    {
            "brand": str = "Brand Name",
            "environment_impact_score": int = 1-5,
            "ethical_practices_score": int = 1-5,
            "animal_welfare_score": int = 1-5,
            "sustainability_initiatives_score": int = 1-5,
            "overall_sustainability_rating": float = 1-5,
            "user_review_score": float = "User Review Score"
            "summary": str = "Brief summary of the evaluation for each of the categories and
                justification for the overall rating",
    }
    Sustainability evaluation should be prioritized when making final recommendations.
"""

root_agent = Agent(
    model=model_config,
    name="sustainable_shopping_assistant",
    description="An agent that assists users in making sustainable shopping choices",
    tools=[AgentTool(agent=shopping_agent), AgentTool(agent=sustainability_evaluation_agent)],
    instruction=instructions,
)

# %%
runner = InMemoryRunner(
    agent=root_agent,
    plugins=[
        LoggingPlugin()
    ]
)
response = await runner.run_debug(
    "Find chrismas chocolate gift boxes."
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Find chrismas chocolate gift boxes.
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-886d7cc4-6834-4ad5-a388-1da9ddb04f9a
# [logging_plugin]    Session ID: debug_session_id
# [logging_plugin]    User ID: debug_user_id
# [logging_plugin]    App Name: InMemoryRunner
# [logging_plugin]    Root Agent: sustainable_shopping_assistant
# [logging_plugin]    User Content: text: 'Find chrismas chocolate gift boxes.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-886d7cc4-6834-4ad5-a388-1da9ddb04f9a
# [logging_plugin]    Starting Agent: sustainable_shopping_assistant
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: sustainable_shopping_assistant
# [logging_plugin]    Invocation ID: e-886d7cc4-6834-4ad5-a388-1da9ddb04f9a
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.0-flash
# [logging_plugin]    Agent: sustainable_shopping_assistant
# [logging_plugin]    System Instruction: '
#     You are a sustainable shopping assistant. Your task is to combine the shopping recommendations
#     from the shopping_agent with the sustainability evaluations from the sustainability_evaluation_a...'
# [logging_plugin]    Available Tools: ['shopping_agent', 'sustainability_evaluation_agent']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: sustainable_shopping_assistant
# [logging_plugin]    Content: function_call: shopping_agent
# [logging_plugin]    Token Usage - Input: 223, Output: 9
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 15c82082-b8ad-4e3e-8821-af9ab50daf1c
# [logging_plugin]    Author: sustainable_shopping_assistant
# [logging_plugin]    Content: function_call: shopping_agent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['shopping_agent']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: shopping_agent
# [logging_plugin]    Agent: sustainable_shopping_assistant
# [logging_plugin]    Function Call ID: adk-4fb48247-5b2b-44e9-8202-42698aff5623
# [logging_plugin]    Arguments: {'request': 'chrismas chocolate gift boxes'}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-f1cf41a2-fdf5-4136-9082-762da882d13a
# [logging_plugin]    Session ID: 5ab9ff5a-138f-4705-85c3-f46039f331a4
# [logging_plugin]    User ID: debug_user_id
# [logging_plugin]    App Name: InMemoryRunner
# [logging_plugin]    Root Agent: shopping_agent
# [logging_plugin]    User Content: text: 'chrismas chocolate gift boxes'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-f1cf41a2-fdf5-4136-9082-762da882d13a
# [logging_plugin]    Starting Agent: shopping_agent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: shopping_agent
# [logging_plugin]    Invocation ID: e-f1cf41a2-fdf5-4136-9082-762da882d13a
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.0-flash
# [logging_plugin]    Agent: shopping_agent
# [logging_plugin]    System Instruction: '
#     You are a helpful shopping assistant. Use the tools provided to find products, compare prices,
#     and provide recommendations based on user preferences.
#     When using the google_search tool, b...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: shopping_agent
# [logging_plugin]    Content: text: 'Here are some Christmas chocolate gift box options from various brands:
#
# *   **Lindt:** Offers a variety of Christmas chocolate boxes, including the Custom LINDOR Pick and Mix Holiday Box (available i...'
# [logging_plugin]    Token Usage - Input: 191, Output: 280
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 98791bd1-4e54-4d52-964a-6dd6f9243ade
# [logging_plugin]    Author: shopping_agent
# [logging_plugin]    Content: text: 'Here are some Christmas chocolate gift box options from various brands:
#
# *   **Lindt:** Offers a variety of Christmas chocolate boxes, including the Custom LINDOR Pick and Mix Holiday Box (available i...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: shopping_agent
# [logging_plugin]    Invocation ID: e-f1cf41a2-fdf5-4136-9082-762da882d13a
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-f1cf41a2-fdf5-4136-9082-762da882d13a
# [logging_plugin]    Final Agent: shopping_agent
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: shopping_agent
# [logging_plugin]    Agent: sustainable_shopping_assistant
# [logging_plugin]    Function Call ID: adk-4fb48247-5b2b-44e9-8202-42698aff5623
# [logging_plugin]    Result: Here are some Christmas chocolate gift box options from various brands:
#
# *   **Lindt:** Offers a variety of Christmas chocolate boxes, including the Custom LINDOR Pick and Mix Holiday Box (available in 50-pc, 75-pc, 100-pc, and 175-pc sizes) and the Lindt Holiday Winter Village Box. They also have o...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: e85654f2-9986-4f19-b434-927c424976b2
# [logging_plugin]    Author: sustainable_shopping_assistant
# [logging_plugin]    Content: function_response: shopping_agent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['shopping_agent']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.0-flash
# [logging_plugin]    Agent: sustainable_shopping_assistant
# [logging_plugin]    System Instruction: '
#     You are a sustainable shopping assistant. Your task is to combine the shopping recommendations
#     from the shopping_agent with the sustainability evaluations from the sustainability_evaluation_a...'
# [logging_plugin]    Available Tools: ['shopping_agent', 'sustainability_evaluation_agent']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: sustainable_shopping_assistant
# [logging_plugin]    Content: function_call: sustainability_evaluation_agent | function_call: sustainability_evaluation_agent | function_call: sustainability_evaluation_agent | function_call: sustainability_evaluation_agent
# [logging_plugin]    Token Usage - Input: 516, Output: 36
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 4de107df-eee2-41a2-b24c-79bcbeb72e27
# [logging_plugin]    Author: sustainable_shopping_assistant
# [logging_plugin]    Content: function_call: sustainability_evaluation_agent | function_call: sustainability_evaluation_agent | function_call: sustainability_evaluation_agent | function_call: sustainability_evaluation_agent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['sustainability_evaluation_agent', 'sustainability_evaluation_agent', 'sustainability_evaluation_agent', 'sustainability_evaluation_agent']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: sustainability_evaluation_agent
# [logging_plugin]    Agent: sustainable_shopping_assistant
# [logging_plugin]    Function Call ID: adk-dec89ce3-72df-4b52-bbfc-4850c96a96ea
# [logging_plugin]    Arguments: {'request': 'Lindt'}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-fe206f6d-ca31-4df3-a4d8-b338a8e55968
# [logging_plugin]    Session ID: 3a0ded56-5db4-4fa5-b7cd-9b9a1de01cd1
# [logging_plugin]    User ID: debug_user_id
# [logging_plugin]    App Name: InMemoryRunner
# [logging_plugin]    Root Agent: sustainability_evaluation_agent
# [logging_plugin]    User Content: text: 'Lindt'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-fe206f6d-ca31-4df3-a4d8-b338a8e55968
# [logging_plugin]    Starting Agent: sustainability_evaluation_agent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: sustainability_evaluation_agent
# [logging_plugin]    Invocation ID: e-fe206f6d-ca31-4df3-a4d8-b338a8e55968
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.0-flash
# [logging_plugin]    Agent: sustainability_evaluation_agent
# [logging_plugin]    System Instruction: '
#     You are a sustainability evaluation agent. Use the tools provided to research companies,
#     focusing on their environmental impact, ethical practices, and sustainability initiatives.
#     You sho...'
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: sustainability_evaluation_agent
# [logging_plugin]    Agent: sustainable_shopping_assistant
# [logging_plugin]    Function Call ID: adk-620a8380-289a-4dbb-8562-33a77d03c3c5
# [logging_plugin]    Arguments: {'request': 'Russell Stover'}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-78d656da-00ca-49a1-82ad-000f0ee1c359
# [logging_plugin]    Session ID: 198d6a71-69b8-4487-b9a2-876c887f0187
# [logging_plugin]    User ID: debug_user_id
# [logging_plugin]    App Name: InMemoryRunner
# [logging_plugin]    Root Agent: sustainability_evaluation_agent
# [logging_plugin]    User Content: text: 'Russell Stover'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-78d656da-00ca-49a1-82ad-000f0ee1c359
# [logging_plugin]    Starting Agent: sustainability_evaluation_agent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: sustainability_evaluation_agent
# [logging_plugin]    Invocation ID: e-78d656da-00ca-49a1-82ad-000f0ee1c359
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.0-flash
# [logging_plugin]    Agent: sustainability_evaluation_agent
# [logging_plugin]    System Instruction: '
#     You are a sustainability evaluation agent. Use the tools provided to research companies,
#     focusing on their environmental impact, ethical practices, and sustainability initiatives.
#     You sho...'
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: sustainability_evaluation_agent
# [logging_plugin]    Agent: sustainable_shopping_assistant
# [logging_plugin]    Function Call ID: adk-76451685-285f-4d6f-a1a6-8ace85d60ad1
# [logging_plugin]    Arguments: {'request': 'Cadbury'}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-39ae52f8-af45-40f4-8964-1980cc26704c
# [logging_plugin]    Session ID: 49af4e0a-564b-4c94-8950-88e7475d543d
# [logging_plugin]    User ID: debug_user_id
# [logging_plugin]    App Name: InMemoryRunner
# [logging_plugin]    Root Agent: sustainability_evaluation_agent
# [logging_plugin]    User Content: text: 'Cadbury'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-39ae52f8-af45-40f4-8964-1980cc26704c
# [logging_plugin]    Starting Agent: sustainability_evaluation_agent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: sustainability_evaluation_agent
# [logging_plugin]    Invocation ID: e-39ae52f8-af45-40f4-8964-1980cc26704c
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.0-flash
# [logging_plugin]    Agent: sustainability_evaluation_agent
# [logging_plugin]    System Instruction: '
#     You are a sustainability evaluation agent. Use the tools provided to research companies,
#     focusing on their environmental impact, ethical practices, and sustainability initiatives.
#     You sho...'
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: sustainability_evaluation_agent
# [logging_plugin]    Agent: sustainable_shopping_assistant
# [logging_plugin]    Function Call ID: adk-a887c299-797f-43fa-9791-5e605627f8a4
# [logging_plugin]    Arguments: {'request': "See's Candies"}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-4ec80f9a-328a-410b-b406-7605a91f7b3f
# [logging_plugin]    Session ID: f42a4cce-e2ec-4d9d-aa59-1cbc8b6f69c8
# [logging_plugin]    User ID: debug_user_id
# [logging_plugin]    App Name: InMemoryRunner
# [logging_plugin]    Root Agent: sustainability_evaluation_agent
# [logging_plugin]    User Content: text: 'See's Candies'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-4ec80f9a-328a-410b-b406-7605a91f7b3f
# [logging_plugin]    Starting Agent: sustainability_evaluation_agent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: sustainability_evaluation_agent
# [logging_plugin]    Invocation ID: e-4ec80f9a-328a-410b-b406-7605a91f7b3f
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.0-flash
# [logging_plugin]    Agent: sustainability_evaluation_agent
# [logging_plugin]    System Instruction: '
#     You are a sustainability evaluation agent. Use the tools provided to research companies,
#     focusing on their environmental impact, ethical practices, and sustainability initiatives.
#     You sho...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: sustainability_evaluation_agent
# [logging_plugin]    Content: text: '```json
# [
#     {
#         "brand": "Lindt",
#         "environment_impact_score": 4,
#         "ethical_practices_score": 3,
#         "animal_welfare_score": 4,
#         "sustainability_initiatives_score": 4,...'
# [logging_plugin]    Token Usage - Input: 759, Output: 229
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 86c9ed90-569a-411a-bc41-9afad4b74d48
# [logging_plugin]    Author: sustainability_evaluation_agent
# [logging_plugin]    Content: text: '```json
# [
#     {
#         "brand": "Lindt",
#         "environment_impact_score": 4,
#         "ethical_practices_score": 3,
#         "animal_welfare_score": 4,
#         "sustainability_initiatives_score": 4,...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: sustainability_evaluation_agent
# [logging_plugin]    Invocation ID: e-fe206f6d-ca31-4df3-a4d8-b338a8e55968
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-fe206f6d-ca31-4df3-a4d8-b338a8e55968
# [logging_plugin]    Final Agent: sustainability_evaluation_agent
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: sustainability_evaluation_agent
# [logging_plugin]    Agent: sustainable_shopping_assistant
# [logging_plugin]    Function Call ID: adk-dec89ce3-72df-4b52-bbfc-4850c96a96ea
# [logging_plugin]    Result: ```json
# [
#     {
#         "brand": "Lindt",
#         "environment_impact_score": 4,
#         "ethical_practices_score": 3,
#         "animal_welfare_score": 4,
#         "sustainability_initiatives_score": 4,
#         "overall_sustainability_rating": 4,
#         "summary": "Lindt has set targets to reduce emi...}
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: sustainability_evaluation_agent
# [logging_plugin]    Content: text: '```json
# [
#     {
#         "brand": "See's Candies",
#         "environment_impact_score": 2,
#         "ethical_practices_score": 3,
#         "animal_welfare_score": 4,
#         "sustainability_initiatives_sc...'
# [logging_plugin]    Token Usage - Input: 762, Output: 225
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 6ae66873-a2f8-49e5-a573-a48960661e3a
# [logging_plugin]    Author: sustainability_evaluation_agent
# [logging_plugin]    Content: text: '```json
# [
#     {
#         "brand": "See's Candies",
#         "environment_impact_score": 2,
#         "ethical_practices_score": 3,
#         "animal_welfare_score": 4,
#         "sustainability_initiatives_sc...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: sustainability_evaluation_agent
# [logging_plugin]    Invocation ID: e-4ec80f9a-328a-410b-b406-7605a91f7b3f
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-4ec80f9a-328a-410b-b406-7605a91f7b3f
# [logging_plugin]    Final Agent: sustainability_evaluation_agent
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: sustainability_evaluation_agent
# [logging_plugin]    Agent: sustainable_shopping_assistant
# [logging_plugin]    Function Call ID: adk-a887c299-797f-43fa-9791-5e605627f8a4
# [logging_plugin]    Result: ```json
# [
#     {
#         "brand": "See's Candies",
#         "environment_impact_score": 2,
#         "ethical_practices_score": 3,
#         "animal_welfare_score": 4,
#         "sustainability_initiatives_score": 2,
#         "overall_sustainability_rating": 3,
#         "summary": "See's Candies demonstrates ...}
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: sustainability_evaluation_agent
# [logging_plugin]    Content: text: 'Here's a sustainability evaluation of Cadbury:' | text: '```json
# [
#     {
#         "brand": "Cadbury",
#         "environment_impact_score": 3,
#         "ethical_practices_score": 2,
#         "animal_welfare_score": 2,
#         "sustainability_initiatives_score": ...'
# [logging_plugin]    Token Usage - Input: 759, Output: 217
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: cd679648-640c-4a1a-8cdb-08db3bb4ce52
# [logging_plugin]    Author: sustainability_evaluation_agent
# [logging_plugin]    Content: text: 'Here's a sustainability evaluation of Cadbury:' | text: '```json
# [
#     {
#         "brand": "Cadbury",
#         "environment_impact_score": 3,
#         "ethical_practices_score": 2,
#         "animal_welfare_score": 2,
#         "sustainability_initiatives_score": ...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: sustainability_evaluation_agent
# [logging_plugin]    Invocation ID: e-39ae52f8-af45-40f4-8964-1980cc26704c
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-39ae52f8-af45-40f4-8964-1980cc26704c
# [logging_plugin]    Final Agent: sustainability_evaluation_agent
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: sustainability_evaluation_agent
# [logging_plugin]    Agent: sustainable_shopping_assistant
# [logging_plugin]    Function Call ID: adk-76451685-285f-4d6f-a1a6-8ace85d60ad1
# [logging_plugin]    Result: Here's a sustainability evaluation of Cadbury:
#
#
# ```json
# [
#     {
#         "brand": "Cadbury",
#         "environment_impact_score": 3,
#         "ethical_practices_score": 2,
#         "animal_welfare_score": 2,
#         "sustainability_initiatives_score": 4,
#         "overall_sustainability_rating": 3,
#     ...}
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: sustainability_evaluation_agent
# [logging_plugin]    Content: text: '```json
# [
#   {
#     "brand": "Russell Stover",
#     "environment_impact_score": 2,
#     "ethical_practices_score": 3,
#     "animal_welfare_score": 2,
#     "sustainability_initiatives_score": 3,
#     "overall...'
# [logging_plugin]    Token Usage - Input: 760, Output: 370
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: f9935c0d-976d-4626-b7ec-0e7ad9ec50e5
# [logging_plugin]    Author: sustainability_evaluation_agent
# [logging_plugin]    Content: text: '```json
# [
#   {
#     "brand": "Russell Stover",
#     "environment_impact_score": 2,
#     "ethical_practices_score": 3,
#     "animal_welfare_score": 2,
#     "sustainability_initiatives_score": 3,
#     "overall...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: sustainability_evaluation_agent
# [logging_plugin]    Invocation ID: e-78d656da-00ca-49a1-82ad-000f0ee1c359
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-78d656da-00ca-49a1-82ad-000f0ee1c359
# [logging_plugin]    Final Agent: sustainability_evaluation_agent
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: sustainability_evaluation_agent
# [logging_plugin]    Agent: sustainable_shopping_assistant
# [logging_plugin]    Function Call ID: adk-620a8380-289a-4dbb-8562-33a77d03c3c5
# [logging_plugin]    Result: ```json
# [
#   {
#     "brand": "Russell Stover",
#     "environment_impact_score": 2,
#     "ethical_practices_score": 3,
#     "animal_welfare_score": 2,
#     "sustainability_initiatives_score": 3,
#     "overall_sustainability_rating": 2,
#     "summary": "Russell Stover, as part of the Lindt & Sprüngli group, s...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 132ca86b-eff4-49ea-8875-4b8f1552e7ea
# [logging_plugin]    Author: sustainable_shopping_assistant
# [logging_plugin]    Content: function_response: sustainability_evaluation_agent | function_response: sustainability_evaluation_agent | function_response: sustainability_evaluation_agent | function_response: sustainability_evaluation_agent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['sustainability_evaluation_agent', 'sustainability_evaluation_agent', 'sustainability_evaluation_agent', 'sustainability_evaluation_agent']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.0-flash
# [logging_plugin]    Agent: sustainable_shopping_assistant
# [logging_plugin]    System Instruction: '
#     You are a sustainable shopping assistant. Your task is to combine the shopping recommendations
#     from the shopping_agent with the sustainability evaluations from the sustainability_evaluation_a...'
# [logging_plugin]    Available Tools: ['shopping_agent', 'sustainability_evaluation_agent']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: sustainable_shopping_assistant
# [logging_plugin]    Content: text: 'Here are some Christmas chocolate gift box options, ranked by sustainability:
#
# ```json
# [
#     {
#         "brand": "Lindt",
#         "overall_sustainability_rating": 4,
#         "summary": "Lindt has set t...'
# [logging_plugin]    Token Usage - Input: 1617, Output: 825
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: e00d7260-29d7-44d6-af78-03e33b1e5991
# [logging_plugin]    Author: sustainable_shopping_assistant
# [logging_plugin]    Content: text: 'Here are some Christmas chocolate gift box options, ranked by sustainability:
#
# ```json
# [
#     {
#         "brand": "Lindt",
#         "overall_sustainability_rating": 4,
#         "summary": "Lindt has set t...'
# [logging_plugin]    Final Response: True
# sustainable_shopping_assistant > Here are some Christmas chocolate gift box options, ranked by sustainability:
#
# ```json
# [
#     {
#         "brand": "Lindt",
#         "overall_sustainability_rating": 4,
#         "summary": "Lindt has set targets to reduce emissions and achieve net-zero by 2050. They aim to have 100% of cocoa products from sustainable sources by 2025. The Lindt & Sprüngli Farming Program is central to their sustainability efforts, focusing on improving cocoa farmer livelihoods and promoting sustainable farming. Lindt has a deforestation policy and aims for no deforestation in cocoa by 2025. However, Lindt has been criticized for human rights issues in its cocoa supply chain and not offering fair trade chocolate. They have a policy banning animal testing. Lindt aims to have over 90% recyclable packaging by 2025."
#     },
#     {
#         "brand": "See's Candies",
#         "overall_sustainability_rating": 3,
#         "summary": "See's Candies demonstrates a mixed approach to sustainability. While they show a commitment to ethical sourcing by using Guittard chocolate and prohibiting human trafficking and slave labor in their operations, their supply chain evaluations are conducted internally, lacking third-party validation. There is also evidence that See's Candies had products containing lead and cadmium. On animal welfare, See's Candies partners with animal welfare organizations like the ASPCA and 15/10 Foundation to support shelter dogs. However, there is limited information available regarding broader environmental initiatives such as carbon footprint reduction or sustainable packaging. This limits their score, resulting in an average overall sustainability rating."
#     },
#     {
#         "brand": "Cadbury",
#         "overall_sustainability_rating": 3,
#         "summary": "Cadbury demonstrates a mixed performance in sustainability. Regarding environmental impact, Cadbury is increasing its use of recycled plastic in packaging. Ethical practices are a concern, with past allegations of child labor and links to deforestation. Cadbury has received criticism for insufficient measures for ensuring human rights, fair wages, sustainability and transparency in their cocoa supply chains. Animal welfare is also a weak point, with concerns about dairy industry practices. However, Cadbury has several sustainability initiatives, including the Cocoa Life program and community development projects. Recent efforts to use recycled packaging and promote sustainable cocoa sourcing are positive steps."
#     },
#     {
#         "brand": "Russell Stover",
#         "overall_sustainability_rating": 2,
#         "summary": "Russell Stover, as part of the Lindt & Sprüngli group, shows some commitment to sustainability but has areas needing improvement. Regarding environmental impact, they aim to reduce their carbon footprint by sourcing packaging and raw materials from domestic US suppliers and improving energy efficiency. However, Russell Stover Candies was fined in 2012 for Clean Water Act violations, indicating past environmental issues. Ethically, Russell Stover has a Supplier Code of Conduct to prevent human trafficking and child labor. They also support legitimate workplace apprenticeship education programs. However, in 2024, investors called on chocolate companies, including Russell Stover, to ensure West African cocoa farmers receive a living income, suggesting ongoing concerns about fair labor practices. For animal welfare, Russell Stover partnered with RedRover to support the human-animal bond. However, there is no information available confirming strong animal welfare policies. As for sustainability initiatives, Russell Stover is increasing its commitment to sustainability by assessing and improving environmental initiatives. As a member of the Lindt & Sprüngli group, their commitments are reported in the annual Lindt & Sprüngli Sustainability Report and they have adopted several policies. Overall, Russell Stover's sustainability rating is 2, indicating below-average performance. While there are some positive initiatives and policies, there are also past environmental violations and ongoing ethical concerns that need to be addressed."
#     }
# ]
# ```
#
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: sustainable_shopping_assistant
# [logging_plugin]    Invocation ID: e-886d7cc4-6834-4ad5-a388-1da9ddb04f9a
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-886d7cc4-6834-4ad5-a388-1da9ddb04f9a
# [logging_plugin]    Final Agent: sustainable_shopping_assistant

# %%
for i, event in enumerate(response):
    content = event.content
    for part in content.parts:
        if part.function_call:
            function_call = part.function_call
            print(f"*** Function Call in Agent {function_call.name} ***")
            pprint.pp(function_call.args["request"], depth=1)
        if part.function_response:
            function_response = part.function_response
            print(f"*** Function Response in Agent {function_response.name} ***")
            pprint.pp(function_response.response["result"], depth=1)
    metadata = event.usage_metadata
    if metadata:
        tokens = metadata.total_token_count
        print(f"Total tokens used in this event: {tokens}")
# Out:
# *** Function Call in Agent shopping_agent ***
# 'chrismas chocolate gift boxes'
# Total tokens used in this event: 232
# *** Function Response in Agent shopping_agent ***
# ('Here are some Christmas chocolate gift box options from various brands:\n'
#  '\n'
#  '*   **Lindt:** Offers a variety of Christmas chocolate boxes, including the '
#  'Custom LINDOR Pick and Mix Holiday Box (available in 50-pc, 75-pc, 100-pc, '
#  'and 175-pc sizes) and the Lindt Holiday Winter Village Box. They also have '
#  'options like the LINDOR Selections Gift Box and the Lindt Connaisseurs '
#  'Selection.\n'
#  '*   **Russell Stover:** Provides Holiday Gift Boxes perfect for chocolate '
#  'lovers, with assorted chocolates like creams, truffles, and chews. They '
#  'offer options like the Christmas Assorted Milk & Dark Chocolate Candy Gift '
#  'Box and the Christmas Caramels in Milk Chocolate Gift Box.\n'
#  '*   **Cadbury:** Features Christmas Chocolate Gifts like the Cadbury '
#  'Christmas Chocolate Gift Box and various Christmas Chocolate Hampers. They '
#  'also have Christmas selection boxes and customizable personalized chocolate '
#  'gifts.\n'
#  "*   **See's Candies:** Offers Christmas Chocolate Gifts & Holiday Treats, "
#  'including the Holiday Joy Box and the Christmas Wonders Tin, filled with '
#  'milk, dark, and white chocolates, truffles, and more. They also have smaller '
#  'assortments like the Christmas Tree Box and Mini Stockings Box.\n'
#  '\n'
#  "I don't have access to live pricing information, and user review scores. "
#  'Please visit the provided URLs to find more details.\n')
# *** Function Call in Agent sustainability_evaluation_agent ***
# 'Lindt'
# *** Function Call in Agent sustainability_evaluation_agent ***
# 'Russell Stover'
# *** Function Call in Agent sustainability_evaluation_agent ***
# 'Cadbury'
# *** Function Call in Agent sustainability_evaluation_agent ***
# "See's Candies"
# Total tokens used in this event: 552
# *** Function Response in Agent sustainability_evaluation_agent ***
# ('```json\n'
#  '[\n'
#  '    {\n'
#  '        "brand": "Lindt",\n'
#  '        "environment_impact_score": 4,\n'
#  '        "ethical_practices_score": 3,\n'
#  '        "animal_welfare_score": 4,\n'
#  '        "sustainability_initiatives_score": 4,\n'
#  '        "overall_sustainability_rating": 4,\n'
#  '        "summary": "Lindt has set targets to reduce emissions and achieve '
#  'net-zero by 2050. They aim to have 100% of cocoa products from sustainable '
#  'sources by 2025. The Lindt & Sprüngli Farming Program is central to their '
#  'sustainability efforts, focusing on improving cocoa farmer livelihoods and '
#  'promoting sustainable farming. Lindt has a deforestation policy and aims for '
#  'no deforestation in cocoa by 2025. However, Lindt has been criticized for '
#  'human rights issues in its cocoa supply chain and not offering fair trade '
#  'chocolate. They have a policy banning animal testing. Lindt aims to have '
#  'over 90% recyclable packaging by 2025."\n'
#  '    }\n'
#  ']\n'
#  '```')
# *** Function Response in Agent sustainability_evaluation_agent ***
# ('```json\n'
#  '[\n'
#  '  {\n'
#  '    "brand": "Russell Stover",\n'
#  '    "environment_impact_score": 2,\n'
#  '    "ethical_practices_score": 3,\n'
#  '    "animal_welfare_score": 2,\n'
#  '    "sustainability_initiatives_score": 3,\n'
#  '    "overall_sustainability_rating": 2,\n'
#  '    "summary": "Russell Stover, as part of the Lindt & Sprüngli group, shows '
#  'some commitment to sustainability but has areas needing improvement. '
#  'Regarding environmental impact, they aim to reduce their carbon footprint by '
#  'sourcing packaging and raw materials from domestic US suppliers and '
#  'improving energy efficiency. However, Russell Stover Candies was fined in '
#  '2012 for Clean Water Act violations, indicating past environmental issues. '
#  'Ethically, Russell Stover has a Supplier Code of Conduct to prevent human '
#  'trafficking and child labor. They also support legitimate workplace '
#  'apprenticeship education programs. However, in 2024, investors called on '
#  'chocolate companies, including Russell Stover, to ensure West African cocoa '
#  'farmers receive a living income, suggesting ongoing concerns about fair '
#  'labor practices. For animal welfare, Russell Stover partnered with RedRover '
#  'to support the human-animal bond. However, there is no information available '
#  'confirming strong animal welfare policies. As for sustainability '
#  'initiatives, Russell Stover is increasing its commitment to sustainability '
#  'by assessing and improving environmental initiatives. As a member of the '
#  'Lindt & Sprüngli group, their commitments are reported in the annual Lindt & '
#  'Sprüngli Sustainability Report and they have adopted several policies. '
#  "Overall, Russell Stover's sustainability rating is 2, indicating "
#  'below-average performance. While there are some positive initiatives and '
#  'policies, there are also past environmental violations and ongoing ethical '
#  'concerns that need to be addressed."\n'
#  '  }\n'
#  ']\n'
#  '```')
# *** Function Response in Agent sustainability_evaluation_agent ***
# ("Here's a sustainability evaluation of Cadbury:\n"
#  '\n'
#  '\n'
#  '```json\n'
#  '[\n'
#  '    {\n'
#  '        "brand": "Cadbury",\n'
#  '        "environment_impact_score": 3,\n'
#  '        "ethical_practices_score": 2,\n'
#  '        "animal_welfare_score": 2,\n'
#  '        "sustainability_initiatives_score": 4,\n'
#  '        "overall_sustainability_rating": 3,\n'
#  '        "summary": "Cadbury demonstrates a mixed performance in '
#  'sustainability. Regarding environmental impact, Cadbury is increasing its '
#  'use of recycled plastic in packaging. Ethical practices are a concern, with '
#  'past allegations of child labor and links to deforestation. Cadbury has '
#  'received criticism for insufficient measures for ensuring human rights, fair '
#  'wages, sustainability and transparency in their cocoa supply chains. Animal '
#  'welfare is also a weak point, with concerns about dairy industry practices. '
#  'However, Cadbury has several sustainability initiatives, including the Cocoa '
#  'Life program and community development projects. Recent efforts to use '
#  'recycled packaging and promote sustainable cocoa sourcing are positive '
#  'steps."\n'
#  '    }\n'
#  ']\n'
#  '```')
# *** Function Response in Agent sustainability_evaluation_agent ***
# ('```json\n'
#  '[\n'
#  '    {\n'
#  '        "brand": "See\'s Candies",\n'
#  '        "environment_impact_score": 2,\n'
#  '        "ethical_practices_score": 3,\n'
#  '        "animal_welfare_score": 4,\n'
#  '        "sustainability_initiatives_score": 2,\n'
#  '        "overall_sustainability_rating": 3,\n'
#  '        "summary": "See\'s Candies demonstrates a mixed approach to '
#  'sustainability. While they show a commitment to ethical sourcing by using '
#  'Guittard chocolate and prohibiting human trafficking and slave labor in '
#  'their operations, their supply chain evaluations are conducted internally, '
#  "lacking third-party validation. There is also evidence that See's Candies "
#  "had products containing lead and cadmium. On animal welfare, See's Candies "
#  'partners with animal welfare organizations like the ASPCA and 15/10 '
#  'Foundation to support shelter dogs. However, there is limited information '
#  'available regarding broader environmental initiatives such as carbon '
#  'footprint reduction or sustainable packaging. This limits their score, '
#  'resulting in an average overall sustainability rating."\n'
#  '    }\n'
#  ']\n'
#  '```')
# Total tokens used in this event: 2442

# %%
# Final recommendations:
print("*** Final Recommendations ***")
pprint.pp(response[-1].content.parts[-1].text, depth=1)
# Out:
# *** Final Recommendations ***
# ('Here are some Christmas chocolate gift box options, ranked by '
#  'sustainability:\n'
#  '\n'
#  '```json\n'
#  '[\n'
#  '    {\n'
#  '        "brand": "Lindt",\n'
#  '        "overall_sustainability_rating": 4,\n'
#  '        "summary": "Lindt has set targets to reduce emissions and achieve '
#  'net-zero by 2050. They aim to have 100% of cocoa products from sustainable '
#  'sources by 2025. The Lindt & Sprüngli Farming Program is central to their '
#  'sustainability efforts, focusing on improving cocoa farmer livelihoods and '
#  'promoting sustainable farming. Lindt has a deforestation policy and aims for '
#  'no deforestation in cocoa by 2025. However, Lindt has been criticized for '
#  'human rights issues in its cocoa supply chain and not offering fair trade '
#  'chocolate. They have a policy banning animal testing. Lindt aims to have '
#  'over 90% recyclable packaging by 2025."\n'
#  '    },\n'
#  '    {\n'
#  '        "brand": "See\'s Candies",\n'
#  '        "overall_sustainability_rating": 3,\n'
#  '        "summary": "See\'s Candies demonstrates a mixed approach to '
#  'sustainability. While they show a commitment to ethical sourcing by using '
#  'Guittard chocolate and prohibiting human trafficking and slave labor in '
#  'their operations, their supply chain evaluations are conducted internally, '
#  "lacking third-party validation. There is also evidence that See's Candies "
#  "had products containing lead and cadmium. On animal welfare, See's Candies "
#  'partners with animal welfare organizations like the ASPCA and 15/10 '
#  'Foundation to support shelter dogs. However, there is limited information '
#  'available regarding broader environmental initiatives such as carbon '
#  'footprint reduction or sustainable packaging. This limits their score, '
#  'resulting in an average overall sustainability rating."\n'
#  '    },\n'
#  '    {\n'
#  '        "brand": "Cadbury",\n'
#  '        "overall_sustainability_rating": 3,\n'
#  '        "summary": "Cadbury demonstrates a mixed performance in '
#  'sustainability. Regarding environmental impact, Cadbury is increasing its '
#  'use of recycled plastic in packaging. Ethical practices are a concern, with '
#  'past allegations of child labor and links to deforestation. Cadbury has '
#  'received criticism for insufficient measures for ensuring human rights, fair '
#  'wages, sustainability and transparency in their cocoa supply chains. Animal '
#  'welfare is also a weak point, with concerns about dairy industry practices. '
#  'However, Cadbury has several sustainability initiatives, including the Cocoa '
#  'Life program and community development projects. Recent efforts to use '
#  'recycled packaging and promote sustainable cocoa sourcing are positive '
#  'steps."\n'
#  '    },\n'
#  '    {\n'
#  '        "brand": "Russell Stover",\n'
#  '        "overall_sustainability_rating": 2,\n'
#  '        "summary": "Russell Stover, as part of the Lindt & Sprüngli group, '
#  'shows some commitment to sustainability but has areas needing improvement. '
#  'Regarding environmental impact, they aim to reduce their carbon footprint by '
#  'sourcing packaging and raw materials from domestic US suppliers and '
#  'improving energy efficiency. However, Russell Stover Candies was fined in '
#  '2012 for Clean Water Act violations, indicating past environmental issues. '
#  'Ethically, Russell Stover has a Supplier Code of Conduct to prevent human '
#  'trafficking and child labor. They also support legitimate workplace '
#  'apprenticeship education programs. However, in 2024, investors called on '
#  'chocolate companies, including Russell Stover, to ensure West African cocoa '
#  'farmers receive a living income, suggesting ongoing concerns about fair '
#  'labor practices. For animal welfare, Russell Stover partnered with RedRover '
#  'to support the human-animal bond. However, there is no information available '
#  'confirming strong animal welfare policies. As for sustainability '
#  'initiatives, Russell Stover is increasing its commitment to sustainability '
#  'by assessing and improving environmental initiatives. As a member of the '
#  'Lindt & Sprüngli group, their commitments are reported in the annual Lindt & '
#  'Sprüngli Sustainability Report and they have adopted several policies. '
#  "Overall, Russell Stover's sustainability rating is 2, indicating "
#  'below-average performance. While there are some positive initiatives and '
#  'policies, there are also past environmental violations and ongoing ethical '
#  'concerns that need to be addressed."\n'
#  '    }\n'
#  ']\n'
#  '```\n')
